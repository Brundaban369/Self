# %% [markdown]
# # Introduction to pandas:
# ## key data structures in pandas:
# -- Series(1 dimentionnal)
#
# -- DataFrame(2 dimentionnal)

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
                   "Age": [25, 30, 35, 40, 45]})

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   45

# %%
df = pd.read_csv("D:/Git/Self/numpylearn/practice.csv")

# %%
df
# Out:
#    First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen  Contoso   555-555-1212           NaN        NaN
# 2      Dorena    Paschke  Contoso   555-555-1212           NaN        NaN
# 3       Kemal      Celik  Contoso   555-555-1212           NaN        NaN
# 4      Shiori      Inoue  Contoso   555-555-1212           NaN        NaN
#
#            E-mail Address
# 0       Anita@contoso.com
# 1  Anne-Mette@contoso.com
# 2     DorenaP@contoso.com
# 3       Kemal@contoso.com
# 4      Shiori@contoso.com

# %%
df.head()
# Out:
#    First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen  Contoso   555-555-1212           NaN        NaN
# 2      Dorena    Paschke  Contoso   555-555-1212           NaN        NaN
# 3       Kemal      Celik  Contoso   555-555-1212           NaN        NaN
# 4      Shiori      Inoue  Contoso   555-555-1212           NaN        NaN
#
#            E-mail Address
# 0       Anita@contoso.com
# 1  Anne-Mette@contoso.com
# 2     DorenaP@contoso.com
# 3       Kemal@contoso.com
# 4      Shiori@contoso.com

# %%
df.describe()
# Out:
#        First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# count           5          5        5              5             1          1
# unique          5          5        1              1             1          1
# top         Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# freq            1          1        5              5             1          1
#
#            E-mail Address
# count                   5
# unique                  5
# top     Anita@contoso.com
# freq                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   First Name      5 non-null      object
#  1   Last Name       5 non-null      object
#  2   Company         5 non-null      object
#  3   Business Phone  5 non-null      object
#  4   Mobile Phone    1 non-null      object
#  5   Birthday        1 non-null      object
#  6   E-mail Address  5 non-null      object
# dtypes: object(7)
# memory usage: 412.0+ bytes

# %%
df.iloc[0]
# Out:
# First Name                    Anita
# Last Name                 Jorgensen
# Company                     Contoso
# Business Phone         555-555-1212
# Mobile Phone           555-555-1212
# Birthday                  1/20/1981
# E-mail Address    Anita@contoso.com
# Name: 0, dtype: object

# %%
df.dropna()
# Out:
#   First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0      Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
#
#       E-mail Address
# 0  Anita@contoso.com

# %%
df.fillna(value=0)
# Out:
#    First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen  Contoso   555-555-1212             0          0
# 2      Dorena    Paschke  Contoso   555-555-1212             0          0
# 3       Kemal      Celik  Contoso   555-555-1212             0          0
# 4      Shiori      Inoue  Contoso   555-555-1212             0          0
#
#            E-mail Address
# 0       Anita@contoso.com
# 1  Anne-Mette@contoso.com
# 2     DorenaP@contoso.com
# 3       Kemal@contoso.com
# 4      Shiori@contoso.com

# %%
df.rename(columns = {"Company": "Organization"})# inplace=True to modify the dataframe in place
# Out:
#    First Name  Last Name Organization Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen      Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen      Contoso   555-555-1212           NaN        NaN
# 2      Dorena    Paschke      Contoso   555-555-1212           NaN        NaN
# 3       Kemal      Celik      Contoso   555-555-1212           NaN        NaN
# 4      Shiori      Inoue      Contoso   555-555-1212           NaN        NaN
#
#            E-mail Address
# 0       Anita@contoso.com
# 1  Anne-Mette@contoso.com
# 2     DorenaP@contoso.com
# 3       Kemal@contoso.com
# 4      Shiori@contoso.com

# %%
len(df)
# Out:
# 5

# %%
df["Zero"] = [0 for i in range(len(df))]

# %%
df
# Out:
#    First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen  Contoso   555-555-1212           NaN        NaN
# 2      Dorena    Paschke  Contoso   555-555-1212           NaN        NaN
# 3       Kemal      Celik  Contoso   555-555-1212           NaN        NaN
# 4      Shiori      Inoue  Contoso   555-555-1212           NaN        NaN
#
#            E-mail Address  Zero
# 0       Anita@contoso.com     0
# 1  Anne-Mette@contoso.com     0
# 2     DorenaP@contoso.com     0
# 3       Kemal@contoso.com     0
# 4      Shiori@contoso.com     0

# %%
def fx(a):
    # Convert 1 to string before concatenation
    return a + str(1)

df["Telicom"] = df["Business Phone"].apply(fx)

# %%
df
# Out:
#    First Name  Last Name  Company Business Phone  Mobile Phone   Birthday  \
# 0       Anita  Jorgensen  Contoso   555-555-1212  555-555-1212  1/20/1981
# 1  Anne-Mette     Olesen  Contoso   555-555-1212           NaN        NaN
# 2      Dorena    Paschke  Contoso   555-555-1212           NaN        NaN
# 3       Kemal      Celik  Contoso   555-555-1212           NaN        NaN
# 4      Shiori      Inoue  Contoso   555-555-1212           NaN        NaN
#
#            E-mail Address  Zero        Telicom
# 0       Anita@contoso.com     0  555-555-12121
# 1  Anne-Mette@contoso.com     0  555-555-12121
# 2     DorenaP@contoso.com     0  555-555-12121
# 3       Kemal@contoso.com     0  555-555-12121
# 4      Shiori@contoso.com     0  555-555-12121

# %%
# command: [df.to_csv("D:/Git/Self/numpylearn/practice2.csv", index=False)] helps to save the dataframe to a new csv file

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
                   "Age": [25, 30, 35, 40, 45],
                   "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"]})

# %%
df1
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eve   45      Phoenix

# %%
df2 = pd.DataFrame({
    "Name": ["ram", "shyam", "hari", "gita", "sita"],
    "Age": [10, 15, 20, 25, 30],  # Match the length of other columns
    "City": ["Kathmandu", "Pokhara", "Biratnagar", "Lalitpur", "Bhaktapur"]
})

# %%
df2
# Out:
#     Name  Age        City
# 0    ram   10   Kathmandu
# 1  shyam   15     Pokhara
# 2   hari   20  Biratnagar
# 3   gita   25    Lalitpur
# 4   sita   30   Bhaktapur

# %%
pd.concat([df1,df2]) # Combine rows of two or more DataFrames
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eve   45      Phoenix
# 0      ram   10    Kathmandu
# 1    shyam   15      Pokhara
# 2     hari   20   Biratnagar
# 3     gita   25     Lalitpur
# 4     sita   30    Bhaktapur
