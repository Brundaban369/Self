# %% [markdown]
# # Netflix project1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                 title   type                     genres  \
# 0                               Ariel  movie       Comedy, Crime, Drama
# 1                 Shadows in Paradise  movie       Comedy, Drama, Music
# 2                        Forrest Gump  movie             Drama, Romance
# 3                     American Beauty  movie                      Drama
# 4                   The Fifth Element  movie  Action, Adventure, Sci-Fi
# ...                               ...    ...                        ...
# 21894      Cheat: Unfinished Business     tv                 Reality-TV
# 21895  Cold Case: The Tylenol Murders     tv         Crime, Documentary
# 21896                             NaN     tv  Animation, Crime, Mystery
# 21897                             NaN     tv                        NaN
# 21898                       Entrapped     tv      Crime, Drama, Mystery
#
#        releaseYear      imdbId  imdbAverageRating  imdbNumVotes  \
# ...

# %%
df.head()
# Out:
#                  title   type                     genres  releaseYear  \
# 0                Ariel  movie       Comedy, Crime, Drama       1988.0
# 1  Shadows in Paradise  movie       Comedy, Drama, Music       1986.0
# 2         Forrest Gump  movie             Drama, Romance       1994.0
# 3      American Beauty  movie                      Drama       1999.0
# 4    The Fifth Element  movie  Action, Adventure, Sci-Fi       1997.0
#
#       imdbId  imdbAverageRating  imdbNumVotes availableCountries
# 0  tt0094675                7.4        9224.0                NaN
# 1  tt0092149                7.4        8053.0                NaN
# 2  tt0109830                8.8     2386990.0                NaN
# 3  tt0169547                8.3     1251274.0                NaN
# 4  tt0119116                7.6      528366.0                NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21899 entries, 0 to 21898
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               21168 non-null  object
#  1   type                21899 non-null  object
#  2   genres              21528 non-null  object
#  3   releaseYear         21859 non-null  float64
#  4   imdbId              20258 non-null  object
#  5   imdbAverageRating   20079 non-null  float64
#  6   imdbNumVotes        20079 non-null  float64
#  7   availableCountries  155 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 1.3+ MB
# None

# %%
print(df.isnull().sum())
# Out:
# title                   731
# type                      0
# genres                  371
# releaseYear              40
# imdbId                 1641
# imdbAverageRating      1820
# imdbNumVotes           1820
# availableCountries    21744
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['title'] = df['title'].str.replace('"', '')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\1285757026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title'] = df['title'].str.replace('"', '')

# %%
df['releaseYear'] = pd.to_numeric(df['releaseYear'], errors='coerce').astype('Int64')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\343452652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['releaseYear'] = pd.to_numeric(df['releaseYear'], errors='coerce').astype('Int64')

# %%
df['imdbAverageRating'] = pd.to_numeric(df['imdbAverageRating'], errors='coerce')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\3269228594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['imdbAverageRating'] = pd.to_numeric(df['imdbAverageRating'], errors='coerce')

# %%
df['imdbNumVotes'] = pd.to_numeric(df['imdbNumVotes'], errors='coerce').astype('Int64')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\3400085197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['imdbNumVotes'] = pd.to_numeric(df['imdbNumVotes'], errors='coerce').astype('Int64')

# %%
df['genres'] = df['genres'].str.replace('"', '').str.split(', ')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\982331628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].str.replace('"', '').str.split(', ')

# %%
df['availableCountries'] = df['availableCountries'].fillna('').str.split(', ')
# Out:
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\1871159191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['availableCountries'] = df['availableCountries'].fillna('').str.split(', ')

# %%
print(df.head())
# Out:
#                  title   type                       genres  releaseYear  \
# 0                Ariel  movie       [Comedy, Crime, Drama]         1988
# 1  Shadows in Paradise  movie       [Comedy, Drama, Music]         1986
# 2         Forrest Gump  movie             [Drama, Romance]         1994
# 3      American Beauty  movie                      [Drama]         1999
# 4    The Fifth Element  movie  [Action, Adventure, Sci-Fi]         1997
#
#       imdbId  imdbAverageRating  imdbNumVotes availableCountries
# 0  tt0094675                7.4          9224                 []
# 1  tt0092149                7.4          8053                 []
# 2  tt0109830                8.8       2386990                 []
# 3  tt0169547                8.3       1251274                 []
# 4  tt0119116                7.6        528366                 []

# %%
df.to_csv('d:\Git\Self\DataScience\cleaned_movies.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\rohid\AppData\Local\Temp\ipykernel_22080\1902369557.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df.to_csv('d:\Git\Self\DataScience\cleaned_movies.csv', index=False)

# %%
print(df.isnull().sum())
# Out:
# title                  326
# type                     0
# genres                 214
# releaseYear             18
# imdbId                1236
# imdbAverageRating     1415
# imdbNumVotes          1415
# availableCountries       0
# dtype: int64

# %%
df
# Out:
#                                           title   type  \
# 0                                         Ariel  movie
# 1                           Shadows in Paradise  movie
# 2                                  Forrest Gump  movie
# 3                               American Beauty  movie
# 4                             The Fifth Element  movie
# ...                                         ...    ...
# 21891  Fred & Rose West: A British Horror Story     tv
# 21894                Cheat: Unfinished Business     tv
# 21895            Cold Case: The Tylenol Murders     tv
# 21896                                       NaN     tv
# 21898                                 Entrapped     tv
#
#                             genres  releaseYear      imdbId  \
# 0           [Comedy, Crime, Drama]         1988   tt0094675
# 1           [Comedy, Drama, Music]         1986   tt0092149
# 2                 [Drama, Romance]         1994   tt0109830
# ...

# %%
df.head()
# Out:
#                  title   type                       genres  releaseYear  \
# 0                Ariel  movie       [Comedy, Crime, Drama]         1988
# 1  Shadows in Paradise  movie       [Comedy, Drama, Music]         1986
# 2         Forrest Gump  movie             [Drama, Romance]         1994
# 3      American Beauty  movie                      [Drama]         1999
# 4    The Fifth Element  movie  [Action, Adventure, Sci-Fi]         1997
#
#       imdbId  imdbAverageRating  imdbNumVotes availableCountries
# 0  tt0094675                7.4          9224                 []
# 1  tt0092149                7.4          8053                 []
# 2  tt0109830                8.8       2386990                 []
# 3  tt0169547                8.3       1251274                 []
# 4  tt0119116                7.6        528366                 []
